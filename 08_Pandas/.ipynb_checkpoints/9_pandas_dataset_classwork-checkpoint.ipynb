# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('demo_data.csv')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.head(7)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
#
#           marital-status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4     Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 32556             0             0              38  United-States  <=50K
# ...

# %%
df.tail(2)
# Out:
#        age     workclass  fnlwgt education  education-num      marital-status  \
# 32559   22       Private  201490   HS-grad              9       Never-married
# 32560   52  Self-emp-inc  287927   HS-grad              9  Married-civ-spouse
#
#             occupation relationship   race     sex  capital-gain  \
# 32559     Adm-clerical    Own-child  White    Male             0
# 32560  Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K

# %%
df.sample(7)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 6871    35           Private  337286       Masters             14
# 26635   53       Federal-gov  290290  Some-college             10
# 22353   52           Private  152373       HS-grad              9
# 29911   50  Self-emp-not-inc  156606  Some-college             10
# 27349   52           Private  222405       HS-grad              9
# 13762   58           Private  123436     Bachelors             13
# 647     71           Private   78277       HS-grad              9
#
#            marital-status         occupation   relationship  \
# 6871        Never-married    Exec-managerial  Not-in-family
# 26635            Divorced       Adm-clerical  Not-in-family
# 22353  Married-civ-spouse  Machine-op-inspct        Husband
# 29911  Married-civ-spouse    Exec-managerial           Wife
# 27349  Married-civ-spouse              Sales        Husband
# 13762  Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
df.sample(frac=0.0002)
# Out:
#        age    workclass  fnlwgt     education  education-num  \
# 9649    39      Private   43712       HS-grad              9
# 8469    21      Private  149224  Some-college             10
# 3806    32  Federal-gov  111567   Prof-school             15
# 9499    19      Private  217769  Some-college             10
# 18849   41      Private   34037       HS-grad              9
# 29913   30    Local-gov  164493  Some-college             10
# 25880   38      Private  175232       HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 9649   Married-civ-spouse    Exec-managerial        Husband  White    Male
# 8469        Never-married   Transport-moving      Own-child  White    Male
# 3806   Married-civ-spouse     Prof-specialty        Husband  White    Male
# 9499        Never-married      Other-service      Own-child  White  Female
# 18849       Never-married  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df['capital-gain'].value_counts()
# Out:
# capital-gain
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: count, Length: 119, dtype: int64

# %%
df['capital-gain'].value_counts(normalize=True)
# Out:
# capital-gain
# 0        0.916710
# 15024    0.010657
# 7688     0.008722
# 7298     0.007555
# 99999    0.004883
#            ...
# 1111     0.000031
# 2538     0.000031
# 22040    0.000031
# 4931     0.000031
# 5060     0.000031
# Name: proportion, Length: 119, dtype: float64

# %%
df['capital-loss'].value_counts(ascending=True)
# Out:
# capital-loss
# 1411        1
# 1539        1
# 2472        1
# 1844        1
# 2489        1
#         ...
# 1848       51
# 1887      159
# 1977      168
# 1902      202
# 0       31042
# Name: count, Length: 92, dtype: int64

# %% [markdown]
# ### 1. How many people of each race are represented?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.race.value_counts()
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
df.race.unique()
# Out:
# array(['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo',
#        'Other'], dtype=object)

# %% [markdown]
# ### 2. What is the average age of men?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df[df.sex == 'Male']['age'].mean().round(1)
# Out:
# 39.4

# %% [markdown]
# ### 3. What is the percentage of people who have a Bachelor's degree?

# %%
df.shape[0]
# Out:
# 32561

# %%
len(df)
# Out:
# 32561

# %%
round(df[df.education == 'Bachelors'].shape[0] / len(df) * 100, 1)
# Out:
# 16.4

# %%
f'People who have a Bachelors degree takes {round(df[df.education == 'Bachelors'].shape[0] / len(df) * 100, 1)}% of all the population'
# Out:
# 'People who have a Bachelors degree takes 16.4% of all the population'

# %% [markdown]
# ### 4. What percentage of people with advanced education (Bachelors, Masters or Doctorate) make more than 50K?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.education.unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
df['education-num'].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8],
#       dtype=int64)

# %%
edu_dict = dict(zip(df.education.unique(), df['education-num'].unique()))
edu_dict
# Out:
# {'Bachelors': 13,
#  'HS-grad': 9,
#  '11th': 7,
#  'Masters': 14,
#  '9th': 5,
#  'Some-college': 10,
#  'Assoc-acdm': 12,
#  'Assoc-voc': 11,
#  '7th-8th': 4,
#  'Doctorate': 16,
#  'Prof-school': 15,
#  '5th-6th': 3,
#  '10th': 6,
#  '1st-4th': 2,
#  'Preschool': 1,
#  '12th': 8}

# %%
df.head(8)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
#
#           marital-status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# ...

# %%
a_edu = df[df['education-num'].isin([13, 14, 16])]

# %%
a_edu.education.unique()
# Out:
# array(['Bachelors', 'Masters', 'Doctorate'], dtype=object)

# %%
round(a_edu[a_edu.salary == '>50K'].shape[0] / len(a_edu) * 100, 1)
# Out:
# 46.5

# %% [markdown]
# ### 5. What percentage of people without advanced education make more than 50K?

# %%
l_edu = df[~df['education-num'].isin([13, 14, 16])]
l_edu.education.unique()
# Out:
# array(['HS-grad', '11th', '9th', 'Some-college', 'Assoc-acdm',
#        'Assoc-voc', '7th-8th', 'Prof-school', '5th-6th', '10th',
#        '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
round(l_edu[l_edu.salary == '>50K'].shape[0] / len(l_edu) * 100, 1)
# Out:
# 17.4

# %% [markdown]
# ### 6. What is the minimum number of hours a person works per week?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df['hours-per-week'].min()
# Out:
# 1

# %% [markdown]
# ### 7. What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?

# %%
min_workers = df[df['hours-per-week'] == df['hours-per-week'].min()]

# %%
round(min_workers[min_workers.salary == '>50K'].shape[0] / len(min_workers) * 100, 1)
# Out:
# 10.0

# %% [markdown]
# ### 8. People from which native country have the highest percentage of those who earn >50K and what is that percentage?

# %%
h_salary = df[df.salary == '>50K']

# %%
h_salary['native-country'].value_counts()
# Out:
# native-country
# United-States         7171
# ?                      146
# Philippines             61
# Germany                 44
# India                   40
# Canada                  39
# Mexico                  33
# England                 30
# Italy                   25
# Cuba                    25
# Japan                   24
# Taiwan                  20
# China                   20
# Iran                    18
# South                   16
# Puerto-Rico             12
# Poland                  12
# France                  12
# Jamaica                 10
# El-Salvador              9
# Greece                   8
# Cambodia                 7
# Hong                     6
# Yugoslavia               6
# Ireland                  5
# Vietnam                  5
# Portugal                 4
# Haiti                    4
# Ecuador                  4
# Thailand                 3
# Hungary                  3
# Guatemala                3
# Scotland                 3
# ...

# %%
df['native-country'].value_counts()
# Out:
# native-country
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# ...

# %%
earnings_table = h_salary['native-country'].value_counts() / df['native-country'].value_counts()

# %%
earnings_table.sort_values(ascending=False).head(1).round(3) * 100
# Out:
# native-country
# Iran    41.9
# Name: count, dtype: float64

# %% [markdown]
# ### 9. What is the most popular occupation for those who are originated from India and earn >50K?

# %%
df[(df['salary'] == '>50K') & (df['native-country'] == 'India')]['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Transport-moving     1
# Sales                1
# Adm-clerical         1
# Name: count, dtype: int64

# %% [markdown]
# # Advanced pandas methods

# %% [markdown]
# **Between**

# %%
x = 1

# %%
0 < 1 < 10
# Out:
# True

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df[30 < df.age < 40]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4440\2503887146.py in ?()
# ----> 1 df[30 < df.age < 40]
#
# C:\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.age.between(30, 40)
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 32556    False
# 32557     True
# 32558    False
# 32559    False
# 32560    False
# Name: age, Length: 32561, dtype: bool

# %%
df[df.age.between(30, 40)]
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 0       39  State-gov   77516     Bachelors             13
# 2       38    Private  215646       HS-grad              9
# 5       37    Private  284582       Masters             14
# 8       31    Private   45781       Masters             14
# 10      37    Private  280464  Some-college             10
# ...    ...        ...     ...           ...            ...
# 32545   39  Local-gov  111499    Assoc-acdm             12
# 32546   37    Private  198216    Assoc-acdm             12
# 32551   32    Private   34066          10th              6
# 32553   32    Private  116138       Masters             14
# 32557   40    Private  154374       HS-grad              9
#
#            marital-status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# 2                Divorced  Handlers-cleaners  Not-in-family
# 5      Married-civ-spouse    Exec-managerial           Wife
# ...

# %% [markdown]
# **Select dtypes**

# %%
df.select_dtypes('object')
# Out:
#               workclass   education      marital-status         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex native-country salary
# ...

# %%
df.select_dtypes(exclude='number')
# Out:
#               workclass   education      marital-status         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex native-country salary
# ...

# %%
df.select_dtypes(include='int')
# Out:
#        age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# [32561 rows x 6 columns]

# %% [markdown]
# **nlargest & nsmallest**

# %%
df.nlargest(5, 'capital-gain')
# Out:
#       age     workclass  fnlwgt    education  education-num  \
# 1246   54  Self-emp-inc  166459  Prof-school             15
# 1368   52       Private  152234      HS-grad              9
# 1482   53  Self-emp-inc  263925      HS-grad              9
# 1528   52       Private  118025    Bachelors             13
# 1616   46       Private  370119  Prof-school             15
#
#           marital-status       occupation relationship                race  \
# 1246  Married-civ-spouse   Prof-specialty      Husband               White
# 1368  Married-civ-spouse  Exec-managerial      Husband  Asian-Pac-Islander
# 1482  Married-civ-spouse            Sales      Husband               White
# 1528  Married-civ-spouse  Exec-managerial      Husband               White
# 1616  Married-civ-spouse   Prof-specialty      Husband               White
#
#        sex  capital-gain  capital-loss  hours-per-week native-country salary
# ...

# %%
df.nlargest(5, 'capital-loss')
# Out:
#        age workclass  fnlwgt     education  education-num marital-status  \
# 8963    90         ?   77053       HS-grad              9        Widowed
# 14756   82   Private  132870       HS-grad              9        Widowed
# 30781   66         ?  186061  Some-college             10        Widowed
# 20416   54   Private  140359       7th-8th              4       Divorced
# 23802   41   Private  264663  Some-college             10      Separated
#
#               occupation   relationship   race     sex  capital-gain  \
# 8963                   ?  Not-in-family  White  Female             0
# 14756    Exec-managerial  Not-in-family  White  Female             0
# 30781                  ?      Unmarried  Black  Female             0
# 20416  Machine-op-inspct      Unmarried  White  Female             0
# 23802     Prof-specialty      Own-child  White  Female             0
#
#        capital-loss  hours-per-week native-country salary
# ...

# %%
df.nsmallest(5, ['age', 'hours-per-week'], keep='all')
# Out:
#        age     workclass  fnlwgt education  education-num marital-status  \
# 9821    17  Self-emp-inc  143034      10th              6  Never-married
# 22928   17             ?  332666      10th              6  Never-married
# 449     17             ?  258872      11th              7  Never-married
# 1389    17       Private   46496      11th              7  Never-married
# 13812   17       Private  195505      10th              6  Never-married
# 26864   17       Private  238628      11th              7  Never-married
# 29226   17       Private  217342      10th              6  Never-married
# 31131   17       Private  277541      11th              7  Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 9821   Other-service    Own-child  White    Male             0             0
# 22928              ?    Own-child  White  Female             0             0
# 449                ?    Own-child  White  Female             0             0
# ...

# %%
df.nsmallest(1, ['age'], keep='all')
# Out:
#        age workclass  fnlwgt education  education-num marital-status  \
# 106     17         ?  304873      10th              6  Never-married
# 209     17   Private   65368      11th              7  Never-married
# 262     17   Private  245918      11th              7  Never-married
# 271     17   Private  191260       9th              5  Never-married
# 335     17   Private  270942   5th-6th              3  Never-married
# ...    ...       ...     ...       ...            ...            ...
# 31772   17         ?  256173      10th              6  Never-married
# 31864   17   Private  214787      12th              8  Never-married
# 31959   17   Private   24090   HS-grad              9  Never-married
# 32282   17   Private  311907      11th              7  Never-married
# 32447   17   Private  117798      10th              6  Never-married
#
#             occupation    relationship   race     sex  capital-gain  \
# 106                  ?       Own-child  White  Female         34095
# ...

# %% [markdown]
# **Replace**

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.replace(0, 1000)
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.replace(['Male', 'Female', 'United-States'], ['M', 'F', 'USA'])
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White   M
# ...

# %%
df.replace(['Male', 'Female'], 'Unknown')
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race      sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White  Unknown
# ...

# %%
df.replace({'White': 'Wh', 'Black': 'Bl'})
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family   Wh    Male
# ...

# %%
df.replace({'capital-gain': {2174: 9999, 0: 1000}, 'capital-loss': {0: 5000}})
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.replace({'age': {39: 'thirty nine'}})
# Out:
#                age         workclass  fnlwgt   education  education-num  \
# 0      thirty nine         State-gov   77516   Bachelors             13
# 1               50  Self-emp-not-inc   83311   Bachelors             13
# 2               38           Private  215646     HS-grad              9
# 3               53           Private  234721        11th              7
# 4               28           Private  338409   Bachelors             13
# ...            ...               ...     ...         ...            ...
# 32556           27           Private  257302  Assoc-acdm             12
# 32557           40           Private  154374     HS-grad              9
# 32558           58           Private  151910     HS-grad              9
# 32559           22           Private  201490     HS-grad              9
# 32560           52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# ...

# %% [markdown]
# **Map & apply**

# %%
df.age.map(np.sqrt)
# Out:
# 0        6.244998
# 1        7.071068
# 2        6.164414
# 3        7.280110
# 4        5.291503
#            ...
# 32556    5.196152
# 32557    6.324555
# 32558    7.615773
# 32559    4.690416
# 32560    7.211103
# Name: age, Length: 32561, dtype: float64

# %%
df.education.map('Has {} degree'.format)
# Out:
# 0         Has Bachelors degree
# 1         Has Bachelors degree
# 2           Has HS-grad degree
# 3              Has 11th degree
# 4         Has Bachelors degree
#                  ...
# 32556    Has Assoc-acdm degree
# 32557       Has HS-grad degree
# 32558       Has HS-grad degree
# 32559       Has HS-grad degree
# 32560       Has HS-grad degree
# Name: education, Length: 32561, dtype: object

# %%
df.age.min()
# Out:
# 17

# %%
df.age.max()
# Out:
# 90

# %%
def age_groups(age):
    if age <= 32:
        return 'Young'
    if age <= 45:
        return 'Adult'
    if age <= 65:
        return 'Mid-life'
    return 'Senior'

# %%
df.age.map(age_groups).value_counts().plot(kind='bar', title='Age groups count')
# Out:
# <Axes: title={'center': 'Age groups count'}, xlabel='age'>

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df[['age', 'race', 'sex']].apply(lambda row: 'The person is a {} {} {} years old'.format(row['race'], row['sex'], row['age']), axis=1)
# Out:
# 0          The person is a White Male 39 years old
# 1          The person is a White Male 50 years old
# 2          The person is a White Male 38 years old
# 3          The person is a Black Male 53 years old
# 4        The person is a Black Female 28 years old
#                            ...
# 32556    The person is a White Female 27 years old
# 32557      The person is a White Male 40 years old
# 32558    The person is a White Female 58 years old
# 32559      The person is a White Male 22 years old
# 32560    The person is a White Female 52 years old
# Length: 32561, dtype: object

# %%
id(1)
# Out:
# 140711539390904

# %%
df.applymap(id).head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4440\1548429633.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(id).head()
#                age      workclass         fnlwgt      education  \
# 0  140711539392120  1799593545008  1799693347632  1799692022576
# 1  140711539392472  1799603604976  1799796730960  1799692022576
# 2  140711539392088  1799644914832  1799796735760  1799644916656
# 3  140711539392568  1799644914832  1799796721744  1799644905520
# 4  140711539391768  1799644914832  1799796720080  1799692022576
#
#      education-num  marital-status     occupation   relationship  \
# 0  140711539391288   1799692020016  1799692012592  1799692012016
# 1  140711539391288   1799692020272  1799692013552  1799644906000
# 2  140711539391160   1799692009712  1799692010160  1799692012016
# 3  140711539391096   1799692020272  1799692010160  1799644906000
# 4  140711539391288   1799692020272  1799692015152  1799644906096
#
# ...

# %%
df.map(id)
# Out:
#                    age      workclass         fnlwgt      education  \
# 0      140711539392120  1799593545008  1799693347632  1799692022576
# 1      140711539392472  1799603604976  1799693351888  1799692022576
# 2      140711539392088  1799644914832  1799796720048  1799644916656
# 3      140711539392568  1799644914832  1799796732720  1799644905520
# 4      140711539391768  1799644914832  1799796720528  1799692022576
# ...                ...            ...            ...            ...
# 32556  140711539391736  1799644914832  1799805605840  1799692024176
# 32557  140711539392152  1799644914832  1799805605808  1799644916656
# 32558  140711539392728  1799644914832  1799805605776  1799644916656
# 32559  140711539391576  1799644914832  1799805605744  1799644916656
# 32560  140711539392536  1799692021616  1799805605712  1799644916656
#
#          education-num  marital-status     occupation   relationship  \
# 0      140711539391288   1799692020016  1799692012592  1799692012016
# ...

# %% [markdown]
# **Cut**

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
pd.cut(df.age, 5, precision=0)
# Out:
# 0        (32.0, 46.0]
# 1        (46.0, 61.0]
# 2        (32.0, 46.0]
# 3        (46.0, 61.0]
# 4        (17.0, 32.0]
#              ...
# 32556    (17.0, 32.0]
# 32557    (32.0, 46.0]
# 32558    (46.0, 61.0]
# 32559    (17.0, 32.0]
# 32560    (46.0, 61.0]
# Name: age, Length: 32561, dtype: category
# Categories (5, interval[float64, right]): [(17.0, 32.0] < (32.0, 46.0] < (46.0, 61.0] < (61.0, 75.0] < (75.0, 90.0]]

# %%
age_groups = pd.cut(df.age, 5, precision=0, labels=['Young', 'Adult', 'Mid-life', 'Senior', 'Elderly'])

# %%
age_groups[age_groups == 'Young']
# Out:
# 4        Young
# 8        Young
# 11       Young
# 12       Young
# 16       Young
#          ...
# 32537    Young
# 32544    Young
# 32555    Young
# 32556    Young
# 32559    Young
# Name: age, Length: 11460, dtype: category
# Categories (5, object): ['Young' < 'Adult' < 'Mid-life' < 'Senior' < 'Elderly']

# %% [markdown]
# **Sort values**

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.sort_values('age')
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 12318   17           Private  127366          11th              7
# 6312    17           Private  132755          11th              7
# 30927   17           Private  108470          11th              7
# 12787   17         Local-gov  308901          11th              7
# 25755   17                 ?   47407          11th              7
# ...    ...               ...     ...           ...            ...
# 24043   90  Self-emp-not-inc   82628       HS-grad              9
# 32277   90           Private  313749       HS-grad              9
# 5104    90           Private   52386  Some-college             10
# 8963    90                 ?   77053       HS-grad              9
# 10210   90  Self-emp-not-inc  282095  Some-college             10
#
#            marital-status       occupation   relationship                race  \
# 12318       Never-married            Sales      Own-child               White
# ...

# %%
df.sort_values('age', ascending=False)
# Out:
#        age workclass  fnlwgt  education  education-num      marital-status  \
# 5406    90   Private   51744    Masters             14       Never-married
# 6624    90   Private  313986       11th              7  Married-civ-spouse
# 20610   90   Private  206667    Masters             14  Married-civ-spouse
# 1040    90   Private  137018    HS-grad              9       Never-married
# 1935    90   Private  221832  Bachelors             13  Married-civ-spouse
# ...    ...       ...     ...        ...            ...                 ...
# 609     17   Private  169658       10th              6       Never-married
# 22928   17         ?  332666       10th              6       Never-married
# 19190   17   Private   29571       12th              8       Never-married
# 19206   17   Private  183066       10th              6       Never-married
# 24954   17   Private  160968       11th              7       Never-married
#
# ...

# %%
df.sort_values(['age', 'hours-per-week'])
# Out:
#        age     workclass  fnlwgt    education  education-num  \
# 9821    17  Self-emp-inc  143034         10th              6
# 22928   17             ?  332666         10th              6
# 449     17             ?  258872         11th              7
# 1389    17       Private   46496         11th              7
# 13812   17       Private  195505         10th              6
# ...    ...           ...     ...          ...            ...
# 10545   90       Private  175491      HS-grad              9
# 11996   90       Private   40388    Bachelors             13
# 5370    90     Local-gov  227796      Masters             14
# 8806    90       Private   87372  Prof-school             15
# 15356   90       Private   90523      HS-grad              9
#
#            marital-status        occupation   relationship   race     sex  \
# 9821        Never-married     Other-service      Own-child  White    Male
# 22928       Never-married                 ?      Own-child  White  Female
# ...

# %%
df.sort_values(['age', 'hours-per-week'], ascending=[True, False])
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 335     17           Private  270942       5th-6th              3
# 4667    17           Private   48610          11th              7
# 9971    17           Private  168807       7th-8th              4
# 30898   17         Local-gov  192387           9th              5
# 431     17                 ?  202521          11th              7
# ...    ...               ...     ...           ...            ...
# 24043   90  Self-emp-not-inc   82628       HS-grad              9
# 4109    90                 ?  256514     Bachelors             13
# 12451   90                 ?  225063  Some-college             10
# 18413   90           Private  313749     Bachelors             13
# 11731   90                 ?   39824       HS-grad              9
#
#       marital-status       occupation    relationship                race  \
# 335    Never-married    Other-service  Other-relative               White
# ...

# %%
df.sort_values('education', key=lambda x: x == 'Masters', ascending=False)
# Out:
#        age     workclass  fnlwgt  education  education-num  \
# 4411    43       Private  304175    Masters             14
# 25491   68     State-gov  202699    Masters             14
# 5771    46       Private  137354    Masters             14
# 27090   34     Local-gov  205704    Masters             14
# 27087   32     Local-gov  230912    Masters             14
# ...    ...           ...     ...        ...            ...
# 11131   22       Private  181313  Assoc-voc             11
# 11130   29       Private  253801    HS-grad              9
# 11129   27       Private  244566       10th              6
# 11127   48     Local-gov  145886  Bachelors             13
# 32560   52  Self-emp-inc  287927    HS-grad              9
#
#            marital-status         occupation   relationship  \
# 4411   Married-civ-spouse     Prof-specialty        Husband
# 25491  Married-civ-spouse     Prof-specialty        Husband
# 5771   Married-civ-spouse       Tech-support        Husband
# ...

# %%
df.sort_index(ascending=False)
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 32560   52      Self-emp-inc  287927     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32557   40           Private  154374     HS-grad              9
# 32556   27           Private  257302  Assoc-acdm             12
# ...    ...               ...     ...         ...            ...
# 4       28           Private  338409   Bachelors             13
# 3       53           Private  234721        11th              7
# 2       38           Private  215646     HS-grad              9
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 0       39         State-gov   77516   Bachelors             13
#
#            marital-status         occupation   relationship   race     sex  \
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
# ...

# %% [markdown]
# ## Groupby

# %%
groups = df.groupby('education')

# %%
groups

# %%
groups.get_group('Masters')
# Out:
#        age         workclass  fnlwgt education  education-num  \
# 5       37           Private  284582   Masters             14
# 8       31           Private   45781   Masters             14
# 19      43  Self-emp-not-inc  292175   Masters             14
# 47      44           Private  128354   Masters             14
# 87      33           Private  202051   Masters             14
# ...    ...               ...     ...       ...            ...
# 32504   50           Private  208630   Masters             14
# 32513   46           Private   42972   Masters             14
# 32544   31           Private  199655   Masters             14
# 32553   32           Private  116138   Masters             14
# 32554   53           Private  321865   Masters             14
#
#            marital-status       occupation   relationship                race  \
# 5      Married-civ-spouse  Exec-managerial           Wife               White
# ...

# %%
df[df.education == 'Masters']
# Out:
#        age         workclass  fnlwgt education  education-num  \
# 5       37           Private  284582   Masters             14
# 8       31           Private   45781   Masters             14
# 19      43  Self-emp-not-inc  292175   Masters             14
# 47      44           Private  128354   Masters             14
# 87      33           Private  202051   Masters             14
# ...    ...               ...     ...       ...            ...
# 32504   50           Private  208630   Masters             14
# 32513   46           Private   42972   Masters             14
# 32544   31           Private  199655   Masters             14
# 32553   32           Private  116138   Masters             14
# 32554   53           Private  321865   Masters             14
#
#            marital-status       occupation   relationship                race  \
# 5      Married-civ-spouse  Exec-managerial           Wife               White
# ...

# %%
df.age.mean()
# Out:
# 38.58164675532078

# %%
groups.age.mean().sort_values().plot(kind='barh')
# Out:
# <Axes: ylabel='education'>

# %%
groups.value_counts().to_frame()
# Out:
#                                                                                                                                                                                                      count
# education    age workclass        fnlwgt education-num marital-status     occupation        relationship   race               sex    capital-gain capital-loss hours-per-week native-country salary
# 10th         17  ?                34019  6             Never-married      ?                 Own-child      White              Male   0            0            20             United-States  <=50K       1
#              28  Private          73037  6             Never-married      Transport-moving  Unmarried      White              Male   0            0            30             United-States  <=50K       1
# ...

# %% [markdown]
# **Agg**

# %%
groups.agg({'age': 'mean'})
# Out:
#                     age
# education
# 10th          37.429796
# 11th          32.355745
# 12th          32.000000
# 1st-4th       46.142857
# 5th-6th       42.885886
# 7th-8th       48.445820
# 9th           41.060311
# Assoc-acdm    37.381443
# Assoc-voc     38.553546
# Bachelors     38.904949
# Doctorate     47.702179
# HS-grad       38.974479
# Masters       44.049913
# Preschool     42.764706
# Prof-school   44.746528
# Some-college  35.756275

# %%
age_df = groups.agg({'age': ['min', 'max']})
age_df
# Out:
#              age
#              min max
# education
# 10th          17  90
# 11th          17  90
# 12th          17  79
# 1st-4th       19  90
# 5th-6th       17  84
# 7th-8th       17  90
# 9th           17  90
# Assoc-acdm    19  90
# Assoc-voc     19  84
# Bachelors     19  90
# Doctorate     24  80
# HS-grad       17  90
# Masters       18  90
# Preschool     19  75
# Prof-school   25  90
# Some-college  17  90

# %%
age_df['age']['min']
# Out:
# education
# 10th            17
# 11th            17
# 12th            17
# 1st-4th         19
# 5th-6th         17
# 7th-8th         17
# 9th             17
# Assoc-acdm      19
# Assoc-voc       19
# Bachelors       19
# Doctorate       24
# HS-grad         17
# Masters         18
# Preschool       19
# Prof-school     25
# Some-college    17
# Name: min, dtype: int64

# %%
age_df.columns
# Out:
# MultiIndex([('age', 'min'),
#             ('age', 'max')],
#            )

# %%
age_df.columns = age_df.columns.map('_'.join)

# %%
age_df
# Out:
#               age_min  age_max
# education
# 10th               17       90
# 11th               17       90
# 12th               17       79
# 1st-4th            19       90
# 5th-6th            17       84
# 7th-8th            17       90
# 9th                17       90
# Assoc-acdm         19       90
# Assoc-voc          19       84
# Bachelors          19       90
# Doctorate          24       80
# HS-grad            17       90
# Masters            18       90
# Preschool          19       75
# Prof-school        25       90
# Some-college       17       90

# %%
age_df.plot(kind='bar', figsize=(12, 6))
# Out:
# <Axes: xlabel='education'>

# %%
groups.agg({'age': ['min', 'max'], 'hours-per-week': 'median'})
# Out:
#              age     hours-per-week
#              min max         median
# education
# 10th          17  90           40.0
# 11th          17  90           40.0
# 12th          17  79           40.0
# 1st-4th       19  90           40.0
# 5th-6th       17  84           40.0
# 7th-8th       17  90           40.0
# 9th           17  90           40.0
# Assoc-acdm    19  90           40.0
# Assoc-voc     19  84           40.0
# Bachelors     19  90           40.0
# Doctorate     24  80           45.0
# HS-grad       17  90           40.0
# Masters       18  90           40.0
# Preschool     19  75           40.0
# Prof-school   25  90           48.0
# Some-college  17  90           40.0

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
groups.workclass.mode()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 groups.workclass.mode()
#
# File C:\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1312, in GroupBy.__getattr__(self, attr)
#    1309 if attr in self.obj:
#    1310     return self[attr]
# -> 1312 raise AttributeError(
#    1313     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1314 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'mode'

# %%
groups.agg({'occupation': pd.Series.mode})
# Out:
#                   occupation
# education
# 10th           Other-service
# 11th           Other-service
# 12th           Other-service
# 1st-4th        Other-service
# 5th-6th        Other-service
# 7th-8th         Craft-repair
# 9th            Other-service
# Assoc-acdm      Adm-clerical
# Assoc-voc       Craft-repair
# Bachelors     Prof-specialty
# Doctorate     Prof-specialty
# HS-grad         Craft-repair
# Masters       Prof-specialty
# Preschool      Other-service
# Prof-school   Prof-specialty
# Some-college    Adm-clerical

# %%
new_groups = df.groupby(['education', 'workclass', 'occupation'])

# %%
ages = new_groups.age.mean().to_frame()
ages
# Out:
#                                                  age
# education    workclass   occupation
# 10th         ?           ?                 33.980000
#              Federal-gov Craft-repair      59.750000
#                          Other-service     43.500000
#              Local-gov   Adm-clerical      54.500000
#                          Craft-repair      41.166667
# ...                                              ...
# Some-college State-gov   Sales             46.500000
#                          Tech-support      28.888889
#                          Transport-moving  43.000000
#              Without-pay Adm-clerical      62.000000
#                          Farming-fishing   48.500000
#
# [756 rows x 1 columns]

# %%
ages.reset_index()
# Out:
#         education    workclass        occupation        age
# 0            10th            ?                 ?  33.980000
# 1            10th  Federal-gov      Craft-repair  59.750000
# 2            10th  Federal-gov     Other-service  43.500000
# 3            10th    Local-gov      Adm-clerical  54.500000
# 4            10th    Local-gov      Craft-repair  41.166667
# ..            ...          ...               ...        ...
# 751  Some-college    State-gov             Sales  46.500000
# 752  Some-college    State-gov      Tech-support  28.888889
# 753  Some-college    State-gov  Transport-moving  43.000000
# 754  Some-college  Without-pay      Adm-clerical  62.000000
# 755  Some-college  Without-pay   Farming-fishing  48.500000
#
# [756 rows x 4 columns]

# %% [markdown]
# ## Pivot table

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.drop(['fnlwgt', 'education-num'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    age         workclass  education      marital-status         occupation  \
# 0   39         State-gov  Bachelors       Never-married       Adm-clerical
# 1   50  Self-emp-not-inc  Bachelors  Married-civ-spouse    Exec-managerial
# 2   38           Private    HS-grad            Divorced  Handlers-cleaners
# 3   53           Private       11th  Married-civ-spouse  Handlers-cleaners
# 4   28           Private  Bachelors  Married-civ-spouse     Prof-specialty
#
#     relationship   race     sex  capital-gain  capital-loss  hours-per-week  \
# 0  Not-in-family  White    Male          2174             0              40
# 1        Husband  White    Male             0             0              13
# 2  Not-in-family  White    Male             0             0              40
# 3        Husband  Black    Male             0             0              40
# 4           Wife  Black  Female             0             0              40
#
#   native-country salary
# 0  United-States  <=50K
# ...

# %%
pd.pivot_table(df, index='sex', values=df.select_dtypes('number'))
# Out:
#               age  capital-gain  capital-loss  hours-per-week
# sex
# Female  36.858230    568.410547     61.187633       36.410361
# Male    39.433547   1329.370078    100.213309       42.428086

# %%
pd.pivot_table(df, index=['sex', 'salary'], values=df.select_dtypes('number'))
# Out:
#                      age  capital-gain  capital-loss  hours-per-week
# sex    salary
# Female <=50K   36.210801    121.986134     47.364470       35.916701
#        >50K    42.125530   4200.389313    173.648855       40.426633
# Male   <=50K   37.147012    165.723823     56.806782       40.693879
#        >50K    44.625788   3971.765836    198.780396       46.366106

# %%
pd.pivot_table(df, index='education', aggfunc={'age': 'median', 'capital-gain': 'sum'})
# Out:
#                age  capital-gain
# education
# 10th          34.0        377468
# 11th          28.0        252740
# 12th          28.0        123010
# 1st-4th       46.0         21147
# 5th-6th       42.0         58615
# 7th-8th       50.0        151125
# 9th           39.0        175834
# Assoc-acdm    36.0        683306
# Assoc-voc     37.0        988201
# Bachelors     37.0       9404984
# Doctorate     47.0       1970070
# HS-grad       37.0       6056978
# Masters       43.0       4415297
# Preschool     41.0         45818
# Prof-school   43.0       5998704
# Some-college  34.0       4366027

# %%
df.head()
# Out:
#    age         workclass  education      marital-status         occupation  \
# 0   39         State-gov  Bachelors       Never-married       Adm-clerical
# 1   50  Self-emp-not-inc  Bachelors  Married-civ-spouse    Exec-managerial
# 2   38           Private    HS-grad            Divorced  Handlers-cleaners
# 3   53           Private       11th  Married-civ-spouse  Handlers-cleaners
# 4   28           Private  Bachelors  Married-civ-spouse     Prof-specialty
#
#     relationship   race     sex  capital-gain  capital-loss  hours-per-week  \
# 0  Not-in-family  White    Male          2174             0              40
# 1        Husband  White    Male             0             0              13
# 2  Not-in-family  White    Male             0             0              40
# 3        Husband  Black    Male             0             0              40
# 4           Wife  Black  Female             0             0              40
#
#   native-country salary
# 0  United-States  <=50K
# ...

# %%
pd.pivot_table(df, index='occupation', columns='education', values=['age'], aggfunc='median')
# Out:
#                     age                                                       \
# education          10th  11th  12th 1st-4th 5th-6th 7th-8th   9th Assoc-acdm
# occupation
# ?                  22.0  21.0  22.0    65.0    56.0    62.0  49.0       32.0
# Adm-clerical       43.5  23.0  26.5     NaN    39.0    55.0  45.5       34.0
# Armed-Forces        NaN   NaN  34.0     NaN     NaN     NaN   NaN        NaN
# Craft-repair       38.5  32.0  35.5    49.0    42.0    47.0  36.0       37.0
# Exec-managerial    48.5  39.5  47.0    54.5    56.0    52.0  53.0       40.0
# Farming-fishing    36.5  35.0  27.5    37.0    37.0    53.5  42.0       44.0
# Handlers-cleaners  28.0  23.0  21.5    34.5    32.0    34.5  36.0       25.0
# Machine-op-inspct  38.0  37.0  32.0    42.0    44.0    49.0  37.0       34.0
# Other-service      27.5  24.0  20.0    45.5    39.0    50.5  41.0       30.5
# Priv-house-serv    21.5  20.0  24.5    54.0    42.0    56.0  51.5       43.5
# ...
